# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size= 0.2, ramdom_state = 43)
tokenizer = Tokenizer(num_words = 10000, oov_token="<OOV>")
tokenizer.fit_on_text(x_train)

x_train_seq = tekenizer.text_to_sequence(x_train)
x_train_pad = pad_sequence(x_train_seq, maxlen = 200)
