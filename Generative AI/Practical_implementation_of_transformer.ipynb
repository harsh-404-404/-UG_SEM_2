# %%
from transformers import pipeline

# load pre-trained transformer pipeline
classifier = pipeline("sentiment-analysis")

# example text
text = "I love learning Transformers. They are amazing !"


# Prediction
result = classifier(text)

# Print the result
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'POSITIVE', 'score': 0.9996678829193115}]

# %%
texts  = [ "This movie is fantastics!",
        "The product is very bad",
         "Average experience , nothing special."]

results = classifier(texts)
for text, res in zip(texts , results):
  print("Text:{text}")
  print(f"Prediction: {res}\n")
# Out:
# Text:{text}
# Prediction: {'label': 'POSITIVE', 'score': 0.9998842477798462}
#
# Text:{text}
# Prediction: {'label': 'NEGATIVE', 'score': 0.9997995495796204}
#
# Text:{text}
# Prediction: {'label': 'NEGATIVE', 'score': 0.9992826581001282}

# %%
#Text generation

# %%
generator = pipeline("text-generation", model="gpt2")
result= generator("Artificial Intelligence ", max_length=30)

print(result)
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
from transformers import pipeline

qa = pipeline("question-answering")

result = qa(
    question="Where do i live",
    context="I live in Himachal Pradesh , India."
)

print(result)
